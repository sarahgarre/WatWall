# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#How-to-use-Jupyter-to-visualize-data-and-perform-calculations" data-toc-modified-id="How-to-use-Jupyter-to-visualize-data-and-perform-calculations-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>How to use Jupyter to visualize data and perform calculations</a></span><ul class="toc-item"><li><span><a href="#Why-Jupyter" data-toc-modified-id="Why-Jupyter-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Why Jupyter</a></span></li><li><span><a href="#Import-data-from-MySQL-database-generated-by-ELSA" data-toc-modified-id="Import-data-from-MySQL-database-generated-by-ELSA-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Import data from MySQL database generated by ELSA</a></span></li><li><span><a href="#Plot-substrate-moisture-status" data-toc-modified-id="Plot-substrate-moisture-status-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Plot substrate moisture status</a></span></li></ul></li></ul></div>

# %% [markdown]
# # How to use Jupyter to visualize data and perform calculations

# %% [markdown]
# ## Why Jupyter
# Jupiter Notebooks allow you to add comments to your Python code using the Markdown language. Very handy if you want to share your code with other people or for yourself to remember what you were doing. You can also generate plots etc. within the notebook, so you directly see output of your code in the notebook.

# %%
# Import necessary python packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Import data from MySQL database generated by ELSA

# %% [markdown]
# ## Plot substrate moisture status
